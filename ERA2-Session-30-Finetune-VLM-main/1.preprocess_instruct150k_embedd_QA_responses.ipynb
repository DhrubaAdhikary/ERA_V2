# %% [markdown]
# \
# **The LLaVA (Large Language and Vision Assistant) dataset** is designed to train and evaluate models that can handle multimodal tasks involving both visual and textual inputs. The dataset is part of a broader trend in AI research, where models are developed to understand and generate language, while also processing visual information like images
#
# **Structure**
#
# ![image.png](attachment:image.png)

# %%
# !sudo apt-get install unzip -q
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# unzip is already the newest version (6.0-26ubuntu3.2).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
import pickle
import json
import requests
import os
from PIL import Image
import pickle
import csv
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
from transformers import AutoProcessor, AutoTokenizer
import random

import torch
from torch.utils.data import Dataset
from torch.utils.data import random_split, DataLoader
from transformers import AutoProcessor, AutoTokenizer

# %% [markdown]
# Step 1 - FETCH INSTRUCT150K DATA

# %%
url = "https://huggingface.co/datasets/liuhaotian/LLaVA-Instruct-150K/resolve/main/llava_instruct_150k.json"
response = requests.get(url)

with open("llava_instruct_150k.json", "wb") as f:
    f.write(response.content)

# %% [markdown]
# The main columns (or keys) are:
#
# 1. **`id`**:  The unique identifier for the dataset entry, in this case `'000000230238'`. It's likely used to differentiate this specific image and its associated conversation from others.
#
# 2. **`image`**: This refers to the image file, `'000000230238.jpg'`, which is the central focus of the dialogue. It indicates the name of the image file that is being referenced in the conversation.
#
# 3. **`conversations`**: This is a list that contains the actual interaction between the human and the AI. Each item in this list is a dictionary with the following sub-keys:
#    - **`from`**: This specifies who is speaking, either `'human'` or `'gpt'`.
#    - **`value`**: This contains the actual content of the question or response. It holds the question asked by the human or the response provided by the AI.
#
# So the main columns (or keys) in the dataset are:
# - `id`
# - `image`
# - `conversations` (with nested keys `from` and `value` for each conversation entry)

# %%
# Opening JSON file - instruct150k
f = open('llava_instruct_150k.json')

# returns JSON object as a dictionary
data = json.load(f)
data[10]
# Out:
# {'id': '000000230238',
#  'image': '000000230238.jpg',
#  'conversations': [{'from': 'human',
#    'value': '\nWhat is the main color of the vase in the image?'},
#   {'from': 'gpt', 'value': 'The main color of the vase in the image is blue.'},
#   {'from': 'human', 'value': 'Where is the vase located?'},
#   {'from': 'gpt',
#    'value': 'The vase is located in a museum, placed on a pedestal on display.'},
#   {'from': 'human', 'value': 'What kind of design is on the vase?'},
#   {'from': 'gpt',
#    'value': 'The vase features blue flowery drawings, which add to its decorative and artistic appeal.'},
#   {'from': 'human',
#    'value': 'Is there a person visible in the background of the image?'},
#   {'from': 'gpt',
#    'value': 'Yes, there is a person visible in the background of the image near the large vase.'},
#   {'from': 'human',
#    'value': 'How is the vase displayed in terms of lighting and background?'},
#   {'from': 'gpt',
#    'value': 'The vase is displayed with a dark background, which helps highlight its blue and white colors and intricate design. The other windows visible in the image might suggest a well-lit environment intended to emphasize the overall showcase setup, making the vase stand out as an important exhibit piece.'}]}

# %% [markdown]
# Step 2 - PREPARE TRAINING DATA

# %% [markdown]
# In data preparation process, a dataset of images and conversations (as described above) to create a flattened structure that can be saved as a pickle file

# %%
# create input pickle file by flattening the data
data_instruct150_flatten = []
r = 0

for a_idx,d in enumerate(data):
    image = d['image']
    image_url = 'http://images.cocodataset.org/train2017/' + image

    conv_iter = iter( d['conversations'])
    # Loops over the dataset data where each item d is a dictionary containing an image reference and conversations
    # related to that image. a_idx is the index of the current entry in the dataset.
    for i in conv_iter:
      # Fetches the next item in the iterator, which should be the corresponding GPT response to the human question.
      # The assumption is that the structure alternates between human and GPT responses.
      gpt_ans = next(conv_iter)
      # Checks the length of the GPT response. If the response exceeds 150 characters,
      # it's skipped to avoid overly long answers (likely for cleaner or more concise data).
      if len(gpt_ans['value']) > 150: # filter out too long answers
          continue
      # Ensures that the current item i is from a human, and the next item gpt_ans is from GPT.
      # This ensures that only valid human-question and GPT-response pairs are processed.
      if i['from'] == 'human' and gpt_ans['from'] == 'gpt':
        # The human question, with any occurrences of '\n' or '\n' removed (to clean up the question text).
        data_instruct150_flatten.append((image_url, i['value'].replace('\n','').replace('\n',''),gpt_ans['value']))

    # Every 10,000 entries, it prints the progress.
    if a_idx % 10000 == 0:
      print(f"{10000 * r} processed")
      r += 1
# Out:
# 0 processed
# 10000 processed
# 20000 processed
# 30000 processed
# 40000 processed
# 50000 processed
# 60000 processed
# 70000 processed
# 80000 processed
# 90000 processed
# 100000 processed
# 110000 processed
# 120000 processed
# 130000 processed
# 140000 processed
# 150000 processed

# %%
data_instruct150_flatten[10]
# Out:
# ('http://images.cocodataset.org/train2017/000000334872.jpg',
#  'What kind of environment are they skiing in?',
#  'They are skiing in a wooded environment, following a trail through the trees while surrounded by snow.')

# %%
'''
Summary
This code:

Loads the tokenizer for the Phi-3 model.
Adds a custom [QA] token, which can be used to mark transitions between a question and its answer.
Adds a [PAD] token to ensure that sequences in batches have uniform lengths for efficient processing.
Retrieves the padding and end-of-sequence tokens to confirm their availability and proper setup.

'''

from transformers import AutoTokenizer

# Load the Phi-3 model's tokenizer
phi_model_name = "microsoft/Phi-3-mini-128k-instruct"
tokenizer = AutoTokenizer.from_pretrained(phi_model_name, trust_remote_code=True)

# Add the custom [QA] token to mark transitions between questions and answers
tokenizer.add_tokens('[QA]')

# Add special tokens for padding and end of sequence handling
tokenizer.add_special_tokens({'pad_token': '[PAD]'})

# Retrieve the pad and eos tokens to confirm the setup
print("Pad Token:", tokenizer.pad_token)  # Should display '[PAD]'
print("EOS Token:", tokenizer.eos_token)  # EOS token might already be included or inferred
# Out:
# tokenizer_config.json:   0%|          | 0.00/3.44k [00:00<?, ?B/s]
# C:\Users\danda\AppData\Roaming\Python\Python39\site-packages\huggingface_hub\file_download.py:157: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\danda\.cache\huggingface\hub\models--microsoft--Phi-3-mini-128k-instruct. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/306 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/599 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Pad Token: [PAD]
# EOS Token: <|endoftext|>

# %%
# # add tokens
# phi_model_name  = "microsoft/Phi-2"
# tokenizer  = AutoTokenizer.from_pretrained(phi_model_name, trust_remote_code=True)
# # The token [QA] could be a special marker that will be used to signify transitions between questions and answers
# tokenizer.add_tokens('[QA]')
# # Padding tokens are used to ensure that all input sequences are of equal length when batching inputs.
# # The {'pad_token': '[PAD]'} creates a new special token that will be used whenever the input sequence needs to be padded,
# # ensuring consistent input lengths for efficient processing.
# # The pad_token (added earlier as [PAD]) is used to fill sequences to a uniform length during batching.
# # The eos_token (end-of-sequence token) is used to indicate the end of a sequence when the model processes or generates text.
# tokenizer.add_special_tokens({'pad_token':'[PAD]'})
# tokenizer.pad_token, tokenizer.eos_token

# %% [markdown]
# Below code is generating a training dataset for fine tuning language model.
#
# Snap to train_token.csv
#
#
#
#
#
#
#
# ![image.png](data:image/png;base64,...)

# %%
# # gpt like training dataset
# # The dataset involves pairing image URLs with question-answer (Q-A) token sequences for training.
# # img_url: URL of the image.
# # input: Input token sequence (question + part of the answer).
# # label: Target token sequence (shifted version of the input to predict the next token).

# with open('train_token.csv', 'w', newline='') as file:
#     writer = csv.writer(file)
#     writer.writerows([['img_url','input','label']])

# train_data_temp = []
# r = 1
# for df in data_instruct150_flatten:

#   image_url = df[0]
#   image_q   = df[1] + ' [QA]'
#   image_a   = df[2] +  tokenizer.eos_token


#   # tokenise using phi-3 instruct model
#   # ques_token: Tokenizes the question using the tokenizer, returning it as a
#   # PyTorch tensor (return_tensors="pt") without attention masks (return_attention_mask=False).
#   # The squeeze(0) removes unnecessary dimensions, leaving a 1D tensor of token IDs for the question.
#   # Similarly, tokenizes the answer and returns it as a 1D tensor of token IDs.
#   ques_token = tokenizer(image_q, return_tensors="pt", return_attention_mask=False)['input_ids'].squeeze(0)
#   ans_token  = tokenizer(image_a, return_tensors="pt", return_attention_mask=False)['input_ids'].squeeze(0)

#   #print(ques_token)
#   #print(ans_token)
#   #break

#   # context_length = len(ques_token): Stores the length of the question token sequence (which will be used later to extract subsequences).
#   context_length = len(ques_token)
#   # combo_q_a = torch.cat([ques_token, ans_token]): Concatenates the question and answer tokens into a single tensor called combo_q_a,
#   # which represents the combined input and output for training.
#   combo_q_a = torch.cat( [ques_token,ans_token])

#   # for al in range(len(ans_token)):: Loops through each token in the answer sequence.
#   # For each iteration, a sliding window is applied to generate input-label pairs.
#   for al in range(len(ans_token)):
#     # Creates an input sequence by extracting context_length tokens starting at index al.
#     input = combo_q_a[al : al + context_length].numpy()
#     # Creates a label sequence by shifting the input sequence by one token (used to predict the next token).
#     label = combo_q_a[al + 1 : al + context_length + 1].numpy()
#     # Appends the image_url, input, and label as a list to the train_data_temp list.
#     train_data_temp.append([image_url,input,label])

#     # When train_data_temp contains 100,000 entries, the data is written to the CSV file in batches to avoid memory overflow.
#     # Writes all the rows in train_data_temp to the CSV file.
#     if len(train_data_temp) >= 100000: # write to the file
#        print(f"Writing to disk after {r * 100000} rows")
#        r += 1
#        with open('train_token.csv', 'a', newline='') as file:
#           writer = csv.writer(file)
#           writer.writerows(train_data_temp)
#        train_data_temp = []


import csv
import torch

# Create a CSV file to store the training data with headers: img_url, input, and label.
with open('train_token.csv', 'w', newline='') as f:
    csv_writer = csv.writer(f)
    csv_writer.writerow(['img_url', 'input', 'label'])

# Initialize an empty list to accumulate data and set batch counters.
batch_data = []
batch_count = 1

# Iterate over each row in the provided dataset.
for entry in data_instruct150_flatten:

    # Extract the image URL, question, and answer from the dataset.
    img_url = entry[0]
    question = entry[1] + ' [QA]'
    answer = entry[2] + tokenizer.eos_token

    # Tokenize both the question and answer sequences.
    q_tokens = tokenizer(question, return_tensors="pt", return_attention_mask=False)['input_ids'].squeeze(0)
    a_tokens = tokenizer(answer, return_tensors="pt", return_attention_mask=False)['input_ids'].squeeze(0)

    # Calculate the context length based on the length of the question tokens.
    context_len = len(q_tokens)

    # Concatenate question and answer tokens for combined input-output sequences.
    combined_tokens = torch.cat([q_tokens, a_tokens])

    # Create input-label pairs by sliding over the answer sequence.
    for idx in range(len(a_tokens)):
        # Extract the input sequence starting at the current index.
        input_seq = combined_tokens[idx: idx + context_len].numpy()
        # Extract the corresponding label sequence, shifted by one token.
        label_seq = combined_tokens[idx + 1: idx + context_len + 1].numpy()
        # Append the current input-label pair along with the image URL to the batch data.
        batch_data.append([img_url, input_seq, label_seq])

        # Write data to the CSV file in batches to manage memory usage.
        if len(batch_data) >= 100000:
            print(f"Writing batch {batch_count * 100000} rows to disk")
            batch_count += 1
            with open('train_token.csv', 'a', newline='') as f:
                csv_writer = csv.writer(f)
                csv_writer.writerows(batch_data)
            # Clear the batch data to free up memory.
            batch_data = []
# Out:
# Writing batch 100000 rows to disk
# Writing batch 200000 rows to disk
# Writing batch 300000 rows to disk
# Writing batch 400000 rows to disk
# Writing batch 500000 rows to disk
# Writing batch 600000 rows to disk
# Writing batch 700000 rows to disk
# Writing batch 800000 rows to disk
# Writing batch 900000 rows to disk
# Writing batch 1000000 rows to disk
# Writing batch 1100000 rows to disk
# Writing batch 1200000 rows to disk
# Writing batch 1300000 rows to disk
# Writing batch 1400000 rows to disk
# Writing batch 1500000 rows to disk
# Writing batch 1600000 rows to disk
# Writing batch 1700000 rows to disk
# Writing batch 1800000 rows to disk
# Writing batch 1900000 rows to disk
# Writing batch 2000000 rows to disk
# Writing batch 2100000 rows to disk
# Writing batch 2200000 rows to disk
# Writing batch 2300000 rows to disk
# Writing batch 2400000 rows to disk
# Writing batch 2500000 rows to disk
# Writing batch 2600000 rows to disk
# Writing batch 2700000 rows to disk
# Writing batch 2800000 rows to disk
# Writing batch 2900000 rows to disk
# Writing batch 3000000 rows to disk
# Writing batch 3100000 rows to disk
# Writing batch 3200000 rows to disk
# Writing batch 3300000 rows to disk
# Writing batch 3400000 rows to disk
# Writing batch 3500000 rows to disk
# Writing batch 3600000 rows to disk

# %% [markdown]
# Step 3 - PYTORCH DATASET AND DATALOADER TESTING

# %%
df_data = pd.read_csv('train_token.csv')
df_data.head(15)
# Out:
#                                               img_url  \
# 0   http://images.cocodataset.org/train2017/000000...
# 1   http://images.cocodataset.org/train2017/000000...
# 2   http://images.cocodataset.org/train2017/000000...
# 3   http://images.cocodataset.org/train2017/000000...
# 4   http://images.cocodataset.org/train2017/000000...
# 5   http://images.cocodataset.org/train2017/000000...
# 6   http://images.cocodataset.org/train2017/000000...
# 7   http://images.cocodataset.org/train2017/000000...
# 8   http://images.cocodataset.org/train2017/000000...
# 9   http://images.cocodataset.org/train2017/000000...
# 10  http://images.cocodataset.org/train2017/000000...
# 11  http://images.cocodataset.org/train2017/000000...
# 12  http://images.cocodataset.org/train2017/000000...
# 13  http://images.cocodataset.org/train2017/000000...
# 14  http://images.cocodataset.org/train2017/000000...
#
#                                                 input  \
# 0   [ 1724   526   278 11955   310   278  3593   2...
# 1   [  526   278 11955   310   278  3593   297   2...
# 2   [  278 11955   310   278  3593   297   278  19...
# 3   [11955   310   278  3593   297   278  1967 299...
# 4   [  310   278  3593   297   278  1967 29973 320...
# 5   [  278  3593   297   278  1967 29973 32011   4...
# 6   [ 3593   297   278  1967 29973 32011   450  35...
# 7   [  297   278  1967 29973 32011   450  3593   2...
# 8   [  278  1967 29973 32011   450  3593   297   2...
# 9   [ 1967 29973 32011   450  3593   297   278  19...
# 10  [29973 32011   450  3593   297   278  1967   3...
# 11  [ 1724  4682   508   367  3595   373   278  12...
# 12  [ 4682   508   367  3595   373   278  1250   3...
# 13  [  508   367  3595   373   278  1250   310   2...
# 14  [  367  3595   373   278  1250   310   278  35...
#
#                                                 label
# 0   [  526   278 11955   310   278  3593   297   2...
# 1   [  278 11955   310   278  3593   297   278  19...
# 2   [11955   310   278  3593   297   278  1967 299...
# 3   [  310   278  3593   297   278  1967 29973 320...
# 4   [  278  3593   297   278  1967 29973 32011   4...
# 5   [ 3593   297   278  1967 29973 32011   450  35...
# 6   [  297   278  1967 29973 32011   450  3593   2...
# 7   [  278  1967 29973 32011   450  3593   297   2...
# 8   [ 1967 29973 32011   450  3593   297   278  19...
# 9   [29973 32011   450  3593   297   278  1967   3...
# 10  [32011   450  3593   297   278  1967   338  47...
# 11  [ 4682   508   367  3595   373   278  1250   3...
# 12  [  508   367  3595   373   278  1250   310   2...
# 13  [  367  3595   373   278  1250   310   278  35...
# 14  [ 3595   373   278  1250   310   278  3593 299...

# %%
# llavadataset, which is used to load and process a question-answer dataset (likely for vision-language models) that combines image data with textual inputs and labels.
class llavadataset(Dataset):
  # This allows the dataset to be used in conjunction with PyTorch's DataLoader to load batches of data for model training or inference.
  def __init__(self, qa_dataset, phi_model_name, clip_model_name, tokenizer):
    self.processor  = AutoProcessor.from_pretrained(clip_model_name)
    self.qa_dataset = qa_dataset

  # It returns the number of rows (or examples) in qa_dataset
  def __len__(self):
    return self.qa_dataset.shape[0]

  def __getitem__(self, idx):
    # to access a single item from the dataset by its index (idx)
    # a tuple of three items: the processed image, the question tokens, and the answer tokens.
    img_url = self.qa_dataset.img_url[idx]
    ques    = torch.tensor(np.array(np.matrix(self.qa_dataset.input[idx]))[0])
    ans     = torch.tensor(np.array(np.matrix(self.qa_dataset.label[idx]))[0])

    # image load
    # Loads the image from the web using the image URL
    image_load = Image.open(requests.get(img_url,stream=True).raw)
    # preprocesses the image using the processor (self.processor) from the CLIP model.
    image_processed = self.processor(images=image_load, return_tensors="pt") ['pixel_values']
    # Removes the first dimension (batch size of 1) from the tensor,
    image_processed = image_processed.squeeze(0)
    return(image_processed , ques, ans)

# %%
clip_model_name = "openai/clip-vit-base-patch32"
csv_file = 'train_token.csv'
qa_dataset = pd.read_csv(csv_file)
# call to llava_dataset for preprocessing
llava_dataset = llavadataset(qa_dataset, phi_model_name, clip_model_name, tokenizer)
# Out:
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.19k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/862k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
llava_dataset[0]
# Out:
# (tensor([[[ 1.1858,  1.1566,  1.1274,  ...,  1.3902,  1.3756,  1.1712],
#           [ 1.2588,  1.2296,  1.1858,  ...,  1.4048,  1.2150,  1.2734],
#           [ 1.4194,  1.3318,  1.2880,  ...,  1.3610,  1.1128,  1.3756],
#           ...,
#           [-0.4346, -0.3762, -0.3762,  ...,  0.8209,  0.7041,  0.9522],
#           [-0.4200, -0.4054, -0.3908,  ...,  0.1493,  0.1639,  0.1055],
#           [-0.4346, -0.4346, -0.3908,  ...,  0.2223,  0.1493,  0.1347]],
#
#          [[ 1.4145,  1.3695,  1.3395,  ...,  1.6397,  1.6247,  1.3995],
#           [ 1.4596,  1.4446,  1.3995,  ...,  1.6397,  1.4446,  1.5046],
#           [ 1.5646,  1.4896,  1.4295,  ...,  1.5946,  1.3395,  1.6096],
#           ...,
#           [-0.4014, -0.3264, -0.3264,  ...,  0.9793,  0.7542,  1.0393],
#           [-0.3564, -0.3414, -0.3264,  ...,  0.2439,  0.2289,  0.1839],
#           [-0.3714, -0.3714, -0.3264,  ...,  0.2439,  0.1989,  0.1839]],
#
#          [[ 1.7904,  1.7904,  1.7477,  ...,  1.9895,  1.9610,  1.7477],
#           [ 1.8473,  1.8331,  1.7904,  ...,  1.9895,  1.8046,  1.8473],
#           [ 1.9326,  1.8899,  1.8331,  ...,  1.9468,  1.7051,  1.9610],
#           ...,
#           [-0.1009, -0.0440, -0.0440,  ...,  1.1647,  0.8661,  1.1932],
#           [-0.0867, -0.0582, -0.0440,  ...,  0.3826,  0.4395,  0.3399],
#           [-0.1151, -0.1009, -0.0440,  ...,  0.4679,  0.4110,  0.3826]]]),
#  tensor([ 1724,   526,   278, 11955,   310,   278,  3593,   297,   278,  1967,
#          29973, 32011]),
#  tensor([  526,   278, 11955,   310,   278,  3593,   297,   278,  1967, 29973,
#          32011,   450]))

# %% [markdown]
# ### Create VALIDATION DATA using same instruct150k data and take 10000 rows of data

# %%
import json
# Opening JSON file - instruct150k
f = open('llava_instruct_150k.json')

# returns JSON object as
# a dictionary
data = json.load(f)

# %%
# create input pickle file by flattening the data
data_instruct150_sample_val_flatten = []
r = 0

for a_idx,d in enumerate(data):
    image = d['image']
    image_url = 'http://images.cocodataset.org/train2017/' + image
    conv_iter = iter( d['conversations'])
    for i in conv_iter:
      gpt_ans = next(conv_iter)
      if len(gpt_ans['value']) > 200: # filter out too long answers
          continue
      if i['from'] == 'human' and gpt_ans['from'] == 'gpt':
        image_q   = i['value'].replace('\n','').replace('\n','') + ' [QA]'
        image_a   = gpt_ans['value'] +  tokenizer.eos_token
        data_instruct150_sample_val_flatten.append([image_url, image_q, image_a ])

    if a_idx % 10000 == 0:
      print(f"{10000 * r} processed")
      r += 1
      if r >= 2:
        break
# Out:
# 0 processed
# 10000 processed

# %%
data_instruct150_sample_val_flatten[123]
# Out:
# ['http://images.cocodataset.org/train2017/000000432526.jpg',
#  'What are the skiers doing on the slope? [QA]',
#  'The skiers have stopped on the side of the slope and are posing for a photo.<|endoftext|>']

# %%
with open('sample_val_data.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows([['img_url','q','a']])

# data
with open('sample_val_data.csv', 'a', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(data_instruct150_sample_val_flatten)

# %%
# create input pickle file by flattening the data
data_instruct150_sample_val_flatten = []
r = 0

for a_idx,d in enumerate(data):
    image = d['image']
    image_url = 'http://images.cocodataset.org/train2017/' + image
    conv_iter = iter( d['conversations'])
    for i in conv_iter:
      gpt_ans = next(conv_iter)
      if len(gpt_ans['value']) > 200: # filter out too long answers
          continue
      if i['from'] == 'human' and gpt_ans['from'] == 'gpt':
        image_q   = i['value'].replace('\n','').replace('\n','') + ' [QA]'
        image_a   = gpt_ans['value'] 
        data_instruct150_sample_val_flatten.append([image_url, image_a ])

    if a_idx % 10000 == 0:
      print(f"{10000 * r} processed")
# Out:
# 0 processed
# 0 processed
# 0 processed
# 0 processed
# 0 processed
# 0 processed
# 0 processed
# 0 processed
# 0 processed
# 0 processed
# 0 processed
# 0 processed
# 0 processed
# 0 processed
# 0 processed
# 0 processed

# %%
data_instruct150_sample_val_flatten
# Out:
# [['http://images.cocodataset.org/train2017/000000033471.jpg',
#   'The bus in the image is white and red.'],
#  ['http://images.cocodataset.org/train2017/000000033471.jpg',
#   'The back of the bus features an advertisement.'],
#  ['http://images.cocodataset.org/train2017/000000033471.jpg',
#   'The bus is driving down the street, which is crowded with people and other vehicles.'],
#  ['http://images.cocodataset.org/train2017/000000052846.jpg',
#   'The cat is positioned on top of the back of the couch in the living room.'],
#  ['http://images.cocodataset.org/train2017/000000052846.jpg',
#   'The cat is coming out from some curtains onto the couch and is sitting or standing on top of it.'],
#  ['http://images.cocodataset.org/train2017/000000052846.jpg',
#   'The color of the curtains near the cat is red.'],
#  ['http://images.cocodataset.org/train2017/000000052846.jpg',
#   'There are lots of pillows on the couch besides the cat.'],
#  ['http://images.cocodataset.org/train2017/000000052846.jpg',
#   'The couch appears to be in a living room setting.'],
#  ['http://images.cocodataset.org/train2017/000000334872.jpg',
#   'The people in the image are cross-country skiing in the woods, as they are skiing on a trail rather than a steep slope.'],
#  ['http://images.cocodataset.org/train2017/000000334872.jpg',
#   'There are two people in the image, both on skis in the snow.'],
#  ['http://images.cocodataset.org/train2017/000000334872.jpg',
#   'They are skiing in a wooded environment, following a trail through the trees while surrounded by snow.'],
#  ['http://images.cocodataset.org/train2017/000000319154.jpg',
#   'The dog in the image is brown.'],
#  ['http://images.cocodataset.org/train2017/000000319154.jpg',
#   'The dog has a red collar.'],
#  ['http://images.cocodataset.org/train2017/000000319154.jpg',
#   'The dog is sitting behind the window.'],
#  ['http://images.cocodataset.org/train2017/000000319154.jpg',
#   'As the dog stares out the window, it appears to feel longingly, perhaps suggesting a desire to be outside or interacting with someone or something that has caught its attention.'],
#  ['http://images.cocodataset.org/train2017/000000319154.jpg',
#   'The dog has shaggy, fuzzy, and furry brown fur, which makes it look cute and cuddly.'],
#  ['http://images.cocodataset.org/train2017/000000398214.jpg',
#   'In the image, there is a street sign and a traffic light above a city road.'],
#  ['http://images.cocodataset.org/train2017/000000398214.jpg',
#   'There are a total of six traffic lights visible in the image.'],
#  ['http://images.cocodataset.org/train2017/000000398214.jpg',
#   'All the traffic lights in the image are showing the color red at the same time.'],
#  ['http://images.cocodataset.org/train2017/000000398214.jpg',
#   'The image is taken in a big city setting with a city street, an overpass, and buildings in the distance.'],
#  ['http://images.cocodataset.org/train2017/000000398214.jpg',
#   'Yes, there are cars visible on the city street in the image.'],
#  ['http://images.cocodataset.org/train2017/000000520873.jpg',
#   'The girl in the image is eating a dessert, which appears to be a graham cracker treat or a cookie sandwich.'],
#  ['http://images.cocodataset.org/train2017/000000520873.jpg',
#   'The girl has blonde hair, and she is wearing a pink shirt.'],
#  ['http://images.cocodataset.org/train2017/000000520873.jpg',
#   'The dessert is on a green plate.'],
#  ['http://images.cocodataset.org/train2017/000000520873.jpg',
#   'The girl is looking up at the camera while taking a bite of her dessert.'],
#  ['http://images.cocodataset.org/train2017/000000520873.jpg',
#   'The girl is eating her dessert at the table.'],
#  ['http://images.cocodataset.org/train2017/000000575173.jpg',
#   'The image shows a large passenger jet belonging to China Airlines.'],
#  ['http://images.cocodataset.org/train2017/000000575173.jpg',
#   'The airplane is on the ground, as it is seen taxiing down the runway next to a body of water.'],
#  ['http://images.cocodataset.org/train2017/000000575173.jpg',
#   'The body of water is located right next to the runway where the airplane is taxiing.'],
#  ['http://images.cocodataset.org/train2017/000000575173.jpg',
#   'The landscape visible around the airplane consists of a runway and a large body of water or lake located next to it.'],
#  ['http://images.cocodataset.org/train2017/000000087286.jpg',
#   'A green street sign is hanging from the traffic light pole.'],
#  ['http://images.cocodataset.org/train2017/000000087286.jpg',
#   'There are two stoplights on the light post.'],
#  ['http://images.cocodataset.org/train2017/000000087286.jpg',
#   'The street sign on the pole is set against a backdrop of a daytime sky.'],
#  ['http://images.cocodataset.org/train2017/000000032286.jpg',
#   'There are seven chocolate-covered doughnuts in the image.'],
#  ['http://images.cocodataset.org/train2017/000000032286.jpg',
#   'The frosting on the doughnuts is chocolate-colored.'],
#  ['http://images.cocodataset.org/train2017/000000032286.jpg',
#   'The doughnuts are placed in a white box, which is sitting on top of a counter.'],
#  ['http://images.cocodataset.org/train2017/000000032286.jpg',
#   'The doughnuts are sitting together on a tray inside the white box.'],
#  ['http://images.cocodataset.org/train2017/000000175217.jpg',
#   'The sink and vanity in the bathroom are beige in color.'],
#  ['http://images.cocodataset.org/train2017/000000175217.jpg',
#   'The toilet in the bathroom is white.'],
#  ['http://images.cocodataset.org/train2017/000000175217.jpg',
#   'Yes, there is a painting hanging on the wall in the bathroom.'],
#  ['http://images.cocodataset.org/train2017/000000175217.jpg',
#   'Marble fixtures or counters are used in the bathroom.'],
#  ['http://images.cocodataset.org/train2017/000000230238.jpg',
#   'The main color of the vase in the image is blue.'],
#  ['http://images.cocodataset.org/train2017/000000230238.jpg',
#   'The vase is located in a museum, placed on a pedestal on display.'],
#  ['http://images.cocodataset.org/train2017/000000230238.jpg',
#   'The vase features blue flowery drawings, which add to its decorative and artistic appeal.'],
#  ['http://images.cocodataset.org/train2017/000000230238.jpg',
#   'Yes, there is a person visible in the background of the image near the large vase.'],
#  ['http://images.cocodataset.org/train2017/000000392166.jpg',
#   'Yes, the man on the skateboard is holding a dog in his arm.'],
#  ['http://images.cocodataset.org/train2017/000000392166.jpg',
#   'The dog being held by the man is brown.'],
#  ['http://images.cocodataset.org/train2017/000000392166.jpg',
#   'The man is riding the skateboard with one hand holding the dog.'],
#  ['http://images.cocodataset.org/train2017/000000521031.jpg',
#   'The main focus of the image is a collection of stuffed toy bears.'],
#  ['http://images.cocodataset.org/train2017/000000521031.jpg',
#   'The stuffed toy bears are placed on a table.'],
#  ['http://images.cocodataset.org/train2017/000000521031.jpg',
#   'These stuffed toy bears come in various sizes.'],
#  ['http://images.cocodataset.org/train2017/000000521031.jpg',
#   "The stuffed toy bears have tags attached to them. These tags might indicate the bears' brand, price, or other information related to their sale or their background."],
#  ['http://images.cocodataset.org/train2017/000000521031.jpg',
#   'The color of the teddy bears in the image is brown.'],
#  ['http://images.cocodataset.org/train2017/000000199318.jpg',
#   'The prominent feature of the large building in the image is the tall clock tower.'],
#  ['http://images.cocodataset.org/train2017/000000199318.jpg',
#   'The image shows a cloudy day.'],
#  ['http://images.cocodataset.org/train2017/000000199318.jpg',
#   'Yes, there is a road passing under a part of the building with the clock tower.'],
#  ['http://images.cocodataset.org/train2017/000000199318.jpg',
#   'The city street beneath the clock tower appears to be empty in the image.'],
#  ['http://images.cocodataset.org/train2017/000000483357.jpg',
#   'The bathroom in the image is white, with white fixtures.'],
#  ['http://images.cocodataset.org/train2017/000000483357.jpg',
#   'The main elements present in the bathroom are the bathtub, toilet, and sink.'],
#  ['http://images.cocodataset.org/train2017/000000483357.jpg',
#   'The bathroom is small in size but very neat and clean, giving it a tidy and well-maintained appearance.'],
#  ['http://images.cocodataset.org/train2017/000000483357.jpg',
#   'The floor in the bathroom is made of tiles.'],
#  ['http://images.cocodataset.org/train2017/000000197680.jpg',
#   'There are two glass walls beside the large tub in the bathroom.'],
#  ['http://images.cocodataset.org/train2017/000000197680.jpg',
#   'A painting can be found above the bathtub in the bathroom.'],
#  ['http://images.cocodataset.org/train2017/000000197680.jpg',
#   'The bathroom has a very elegant appearance, with features such as a large tub, tiled floors, and the tiles reflecting off the tub, contributing to its sophisticated look.'],
#  ['http://images.cocodataset.org/train2017/000000197680.jpg',
#   'The large tub in the bathroom is made of marble.'],
#  ['http://images.cocodataset.org/train2017/000000197680.jpg',
#   'The bathroom has tiled flooring.'],
#  ['http://images.cocodataset.org/train2017/000000121795.jpg',
#   'Yes, there is a person standing next to some blue water in the image.'],
#  ['http://images.cocodataset.org/train2017/000000121795.jpg',
#   'The sky in the image appears to be cloudy.'],
#  ['http://images.cocodataset.org/train2017/000000121795.jpg',
#   'Yes, the silhouette of the adult is visible in the image, as it is lit by the setting sun over the waterway.'],
#  ['http://images.cocodataset.org/train2017/000000341431.jpg',
#   'The image captures a night scene.'],
#  ['http://images.cocodataset.org/train2017/000000341431.jpg',
#   'The street is illuminated by many street lights and the bright lights from the surrounding buildings. Additionally, there is a time lapse effect causing blurred lights on the road.'],
#  ['http://images.cocodataset.org/train2017/000000341431.jpg',
#   'Yes, there is a notable piece of architecture in the image: a cathedral can be seen across the street, adding to the overall ambiance of the scene.'],
#  ['http://images.cocodataset.org/train2017/000000341431.jpg',
#   'In the middle of the street, there is a decorative pillar that serves as a divider for the road.'],
#  ['http://images.cocodataset.org/train2017/000000300011.jpg',
#   'A food service truck is parked in front of the Kingfisher airplane.'],
#  ['http://images.cocodataset.org/train2017/000000300011.jpg',
#   "The airplane is on the tarmac at the airport, and it's being resupplied with food by the food service truck."],
#  ['http://images.cocodataset.org/train2017/000000300011.jpg',
#   'The airplane in the image is a passenger plane.'],
#  ['http://images.cocodataset.org/train2017/000000300011.jpg',
#   'Yes, the image shows an airport with several airplanes docked at terminals.'],
#  ['http://images.cocodataset.org/train2017/000000120375.jpg',
#   'A red sports utility vehicle (SUV) is driving down the street in the image.'],
#  ['http://images.cocodataset.org/train2017/000000120375.jpg',
#   'Yes, the street is filled with a considerable number of people, which indicates that the area is busy.'],
#  ['http://images.cocodataset.org/train2017/000000120375.jpg',
#   'There is a colorful sign above the car as it drives down the street.'],
#  ['http://images.cocodataset.org/train2017/000000120375.jpg',
#   'The surroundings of the street consist of tall buildings, which is characteristic of a city environment.'],
#  ['http://images.cocodataset.org/train2017/000000179037.jpg',
#   'There is a loaded pizza pie with toppings inside the box in the image.'],
#  ['http://images.cocodataset.org/train2017/000000179037.jpg',
#   'The pizza box is placed on the grass.'],
#  ['http://images.cocodataset.org/train2017/000000179037.jpg',
#   'The pizza box is open, and the whole pizza with toppings is visible.'],
#  ['http://images.cocodataset.org/train2017/000000179037.jpg',
#   'From the image, it appears to be a large pizza.'],
#  ['http://images.cocodataset.org/train2017/000000376970.jpg',
#   'The bathroom in the image is all white.'],
#  ['http://images.cocodataset.org/train2017/000000376970.jpg',
#   'The bathroom has a bathtub.'],
#  ['http://images.cocodataset.org/train2017/000000376970.jpg',
#   'There is a white, wooden cabinet above the toilet.'],
#  ['http://images.cocodataset.org/train2017/000000376970.jpg',
#   'In addition to the white bathtub, toilet, and sink, the bathroom also features a tissue roll holder, a shelving unit over the commode, and a towel.'],
#  ['http://images.cocodataset.org/train2017/000000376970.jpg',
#   'Yes, the walls in the bathroom are covered with white tiles.'],
#  ['http://images.cocodataset.org/train2017/000000043464.jpg',
#   'In the image, there are two traffic signs on a post: a "Stop" sign and a "One Way" sign.'],
#  ['http://images.cocodataset.org/train2017/000000043464.jpg',
#   'The "One Way" sign is positioned above the "Stop" sign on the post.'],
#  ['http://images.cocodataset.org/train2017/000000043464.jpg',
#   'The sky in the image is cloudy.'],
#  ['http://images.cocodataset.org/train2017/000000043464.jpg',
#   'The stop sign is placed on a pole on the side of a street.'],
#  ['http://images.cocodataset.org/train2017/000000326761.jpg',
#   'The image shows an old black and white television set.'],
#  ['http://images.cocodataset.org/train2017/000000326761.jpg',
#   'There is a picture of a car being displayed on the television screen.'],
#  ['http://images.cocodataset.org/train2017/000000326761.jpg',
#   'The television is mounted on a wall with cords visible behind it.'],
#  ['http://images.cocodataset.org/train2017/000000326761.jpg',
#   'Yes, there is a light reflecting off the television screen, which is somewhat affecting the visibility of the car displayed on it.'],
#  ['http://images.cocodataset.org/train2017/000000269327.jpg',
#   "The cake in the image is designed to look like a nurse's hat."],
#  ['http://images.cocodataset.org/train2017/000000269327.jpg',
#   "The cake is in the shape of a nurse's hat."],
#  ['http://images.cocodataset.org/train2017/000000269327.jpg',
#   'The words "Congratulations Danielle" are written on the cake.'],
#  ['http://images.cocodataset.org/train2017/000000023444.jpg',
#   'The appliance shown in the image is a toaster oven.'],
#  ['http://images.cocodataset.org/train2017/000000023444.jpg',
#   'Yes, there is a temperature gauge attached to the toaster oven in the image.'],
#  ['http://images.cocodataset.org/train2017/000000023444.jpg',
#   'As the image shows a toaster oven and not a microwave, there is no sign of a bug or timer in a microwave. The focus should be on the toaster oven and the attached temperature gauge.'],
#  ['http://images.cocodataset.org/train2017/000000108113.jpg',
#   'The dog is sitting next to the donut pillow.'],
#  ['http://images.cocodataset.org/train2017/000000108113.jpg',
#   'The dog is accompanied by a pillow shaped like a donut in the image.'],
#  ['http://images.cocodataset.org/train2017/000000108113.jpg',
#   'The dog is wearing a sweater in the image.'],
#  ['http://images.cocodataset.org/train2017/000000108113.jpg',
#   'The dog appears to be small, with brown and black fur.'],
#  ['http://images.cocodataset.org/train2017/000000108113.jpg',
#   'The dog is sitting on a pile of blankets and is under the stuffed donut pillow.'],
#  ['http://images.cocodataset.org/train2017/000000239114.jpg',
#   'The vase contains a bouquet of purple tulips.'],
#  ['http://images.cocodataset.org/train2017/000000239114.jpg',
#   'The vase is sitting on a small glass table.'],
#  ['http://images.cocodataset.org/train2017/000000239114.jpg',
#   'The flowers are held in a glass vase.'],
#  ['http://images.cocodataset.org/train2017/000000239114.jpg',
#   'Yes, the small table with the vase of flowers is situated by a window.'],
#  ['http://images.cocodataset.org/train2017/000000048937.jpg',
#   'There are two women in the image holding toothbrushes.'],
#  ['http://images.cocodataset.org/train2017/000000048937.jpg',
#   'The women are standing near some shelves or a storage area that contains a bunch of files.'],
#  ['http://images.cocodataset.org/train2017/000000048937.jpg',
#   "It's unclear whether the women are actively brushing their teeth in the image, but they are both holding toothbrushes. They may be reacting to the different types of toothbrushes or discussing them."],
#  ['http://images.cocodataset.org/train2017/000000037662.jpg',
#   'In the scene, there are a cap, a baseball glove, a baseball, and some green grass.'],
#  ['http://images.cocodataset.org/train2017/000000037662.jpg',
#   'The color of the cap is red.'],
#  ['http://images.cocodataset.org/train2017/000000037662.jpg',
#   'There is a coat-of-arms located on the cap.'],
#  ['http://images.cocodataset.org/train2017/000000037662.jpg',
#   'The baseball glove is placed on the green grass with the baseball sitting inside it. The red cap with the coat-of-arms is sitting on top of the baseball glove and the baseball.'],
#  ['http://images.cocodataset.org/train2017/000000055534.jpg',
#   'The bird is perched on a branch of a tree, looking up at the surrounding branches or leaves.'],
#  ['http://images.cocodataset.org/train2017/000000055534.jpg',
#   'The background of the image consists of green leaves, providing a natural setting for the bird in the tree.'],
#  ['http://images.cocodataset.org/train2017/000000432526.jpg',
#   'There are four skiers in the group.'],
#  ['http://images.cocodataset.org/train2017/000000432526.jpg',
#   'The skiers have stopped on the side of the slope and are posing for a photo.'],
#  ['http://images.cocodataset.org/train2017/000000432526.jpg',
#   'The skiers are standing on the side of the snow-covered slope.'],
#  ['http://images.cocodataset.org/train2017/000000565444.jpg',
#   'The man is wearing a Harley Davidson jacket and a leather jacket while sitting on the motorcycle.'],
#  ['http://images.cocodataset.org/train2017/000000565444.jpg',
#   'The man is sitting on the motorcycle on the street.'],
#  ['http://images.cocodataset.org/train2017/000000565444.jpg',
#   'The image of the man and the motorcycle is captured using sepia photography, which brings out the intricacies of the motorcycle.'],
#  ['http://images.cocodataset.org/train2017/000000551172.jpg',
#   'There are two people snowboarding in the image.'],
#  ['http://images.cocodataset.org/train2017/000000551172.jpg',
#   'The two people are engaged in snowboarding, which involves riding down a snow-covered slope on a snowboard.'],
#  ['http://images.cocodataset.org/train2017/000000551172.jpg',
#   'The two snowboarders are riding side by side, which suggests that they are close to each other as they descend the hill.'],
#  ['http://images.cocodataset.org/train2017/000000225479.jpg',
#   'The weather in the image is cloudy, with a cloudy sky visible over the city street.'],
#  ['http://images.cocodataset.org/train2017/000000225479.jpg',
#   'The image shows a city street with ongoing traffic. There is no outdoor arena visible in the photograph.'],
#  ['http://images.cocodataset.org/train2017/000000225479.jpg',
#   'The street light is green, which indicates that cars can proceed and continue driving through the city traffic.'],
#  ['http://images.cocodataset.org/train2017/000000225479.jpg',
#   'Yes, there are cars visible in the image. They are driving through the city traffic on the cloudy day, following the green light signal to proceed.'],
#  ['http://images.cocodataset.org/train2017/000000225479.jpg',
#   'The image is taken from a viewpoint in the middle of the street, allowing for a clear view of the ongoing traffic and street conditions.'],
#  ['http://images.cocodataset.org/train2017/000000108287.jpg',
#   'The bed frame in the image is a sleigh style bed frame.'],
#  ['http://images.cocodataset.org/train2017/000000108287.jpg',
#   'The bed is a queen-sized bed.'],
#  ['http://images.cocodataset.org/train2017/000000108287.jpg',
#   'The bed appears partially untidy or unmade, as the blanket and sheets are pulled down or turned back on one side, while the other side is made and looks neat.'],
#  ['http://images.cocodataset.org/train2017/000000108287.jpg',
#   'The blankets on the bed are brown in color.'],
#  ['http://images.cocodataset.org/train2017/000000481820.jpg',
#   'The vase is filled with a bouquet of sunflowers and roses, which are mixed with other flowers. The colors of the flowers include yellow and red.'],
#  ['http://images.cocodataset.org/train2017/000000481820.jpg',
#   'The table on which the vase is placed is black in color.'],
#  ['http://images.cocodataset.org/train2017/000000481820.jpg',
#   'A white chair is also visible in the image, located next to the black table with the vase of flowers.'],
#  ['http://images.cocodataset.org/train2017/000000481820.jpg',
#   'The vase containing the flowers is made of glass.'],
#  ['http://images.cocodataset.org/train2017/000000331832.jpg',
#   'There are two men in the image.'],
#  ['http://images.cocodataset.org/train2017/000000331832.jpg',
#   'The two men are sitting at a table and eating pizza from boxes.'],
#  ['http://images.cocodataset.org/train2017/000000331832.jpg',
#   'Each of the two men has his own pizza box, suggesting that they are eating separate pizzas but sharing the experience of eating together.'],
#  ['http://images.cocodataset.org/train2017/000000331832.jpg',
#   'The men are seated together at a table, which fosters a sense of camaraderie and companionship as they enjoy their meal.'],
#  ['http://images.cocodataset.org/train2017/000000508913.jpg',
#   'The image features a Lucey Transport LTD truck, which is a large transport or big rig truck.'],
#  ['http://images.cocodataset.org/train2017/000000508913.jpg',
#   'The truck is green in color.'],
#  ['http://images.cocodataset.org/train2017/000000508913.jpg',
#   'The truck is driving on the left-hand side of the road.'],
#  ['http://images.cocodataset.org/train2017/000000508913.jpg',
#   'The image shows a street scene in a city, with the primary focus on the green Lucey Transport LTD truck driving on its way, possibly to deliver goods to its destination.'],
#  ['http://images.cocodataset.org/train2017/000000317730.jpg',
#   'The man in the image is holding a white surfboard.'],
#  ['http://images.cocodataset.org/train2017/000000317730.jpg',
#   'The surfboard has an image of a woman on it. More specifically, it is decorated with a drawing of a hula girl.'],
#  ['http://images.cocodataset.org/train2017/000000296706.jpg',
#   'There is a herd of zebras in the image; the exact number cannot be determined, but it is clear that there are multiple zebras present.'],
#  ['http://images.cocodataset.org/train2017/000000296706.jpg',
#   'The landscape in the image is a dusty, rocky plain, likely in a desert environment.'],
#  ['http://images.cocodataset.org/train2017/000000296706.jpg',
#   'Yes, there are two zebras mating in the midst of the pack of zebras.'],
#  ['http://images.cocodataset.org/train2017/000000296706.jpg',
#   'While the two zebras are mating, the other zebras in the herd are eating and engaging in various activities typical for a herd of zebras.'],
#  ['http://images.cocodataset.org/train2017/000000523795.jpg',
#   'There are two giraffes in the image.'],
#  ['http://images.cocodataset.org/train2017/000000523795.jpg',
#   'The setting is a grassy field, and it is during the day.'],
#  ['http://images.cocodataset.org/train2017/000000523795.jpg',
#   'The giraffes are standing next to each other on the field. They might be walking away from a tree that has fencing around it.'],
#  ['http://images.cocodataset.org/train2017/000000226053.jpg',
#   'Yes, there is a small building on the side of a cliff near the water in the image.'],
#  ['http://images.cocodataset.org/train2017/000000226053.jpg',
#   'The water body present next to the cliff in the image is the ocean.'],
#  ['http://images.cocodataset.org/train2017/000000226053.jpg',
#   'A train can be seen passing by a rocky area next to the river.'],
#  ['http://images.cocodataset.org/train2017/000000379830.jpg',
#   'The owl is next to a wire fence, specifically, a chain-link fence.'],
#  ['http://images.cocodataset.org/train2017/000000379830.jpg',
#   'The owl is surrounded by plants, trees, and bushes, with a few leaves visible in the immediate vicinity.'],
#  ['http://images.cocodataset.org/train2017/000000379830.jpg',
#   'The owl appears to be sitting in the image.'],
#  ['http://images.cocodataset.org/train2017/000000379830.jpg',
#   "The color of the owl's eyes is red."],
#  ['http://images.cocodataset.org/train2017/000000379830.jpg',
#   'The photo is taken from a close perspective, offering a detailed view of the owl and its features.'],
#  ['http://images.cocodataset.org/train2017/000000103910.jpg',
#   'In the bathroom shown in the image, there is a bathtub, a separate shower stall, a towel, and a framed picture.'],
#  ['http://images.cocodataset.org/train2017/000000218990.jpg',
#   'In the image, we can identify squash, bananas, and mushrooms among the pile of fresh fruits and vegetables.'],
#  ['http://images.cocodataset.org/train2017/000000218990.jpg',
#   'The fruits and vegetables are arranged on top of a counter or a table.'],
#  ['http://images.cocodataset.org/train2017/000000218990.jpg',
#   'No, the image mainly focuses on the fresh fruits and vegetables arranged in a group or pile.'],
#  ['http://images.cocodataset.org/train2017/000000445731.jpg',
#   'There are two cats in the image.'],
#  ['http://images.cocodataset.org/train2017/000000445731.jpg',
#   'The cats are resting, cuddling, and sleeping together in a pet bed.'],
#  ['http://images.cocodataset.org/train2017/000000445731.jpg',
#   'The pet bed with the two cats resting in it is placed upon a queen-sized bed.'],
#  ['http://images.cocodataset.org/train2017/000000445731.jpg',
#   'Yes, one of the cats is licking the other cat while they are resting in the pet bed together. This action likely signifies affection and bonding between the two cats.'],
#  ['http://images.cocodataset.org/train2017/000000437994.jpg',
#   'There is a stone bridge present in the image.'],
#  ['http://images.cocodataset.org/train2017/000000437994.jpg',
#   'The stone bridge has an arched shape.'],
#  ['http://images.cocodataset.org/train2017/000000437994.jpg',
#   'Swans can be seen swimming under the bridge.'],
#  ['http://images.cocodataset.org/train2017/000000437994.jpg',
#   'The bridge is located over a pond or a river, as both swans and boats are present in the water underneath the bridge.'],
#  ['http://images.cocodataset.org/train2017/000000437994.jpg',
#   'Yes, there are boats in the image. They are floating in the pond or river, underneath the bridge, along with the swans.'],
#  ['http://images.cocodataset.org/train2017/000000358088.jpg',
#   'The image shows a large white boat, which could be described as a yacht, sitting in the water.'],
#  ['http://images.cocodataset.org/train2017/000000358088.jpg',
#   'The weather in the image is cloudy, suggesting that it might be a slightly overcast day.'],
#  ['http://images.cocodataset.org/train2017/000000358088.jpg',
#   'The boat is stationary in the image, either sitting in the water or moored at a dock.'],
#  ['http://images.cocodataset.org/train2017/000000358088.jpg',
#   'Yes, the boat has a flag on the front of it.'],
#  ['http://images.cocodataset.org/train2017/000000098543.jpg',
#   'The train in the image is yellow and blue.'],
#  ['http://images.cocodataset.org/train2017/000000098543.jpg',
#   'The setting of the photo is a countryside, with a forest nearby. The train is traveling on railroad tracks surrounded by this natural landscape.'],
#  ['http://images.cocodataset.org/train2017/000000098543.jpg',
#   'There are several train tracks in the image. A train is visible in the background, which indicates the presence of multiple tracks parallel to one another.'],
#  ['http://images.cocodataset.org/train2017/000000098543.jpg',
#   'Yes, the train is pulling several cars down the track. There is also another group of cars in the background, suggesting that this might be a busy railroad area.'],
#  ['http://images.cocodataset.org/train2017/000000109095.jpg',
#   'The person in the image is a railroad worker or a train station operator.'],
#  ['http://images.cocodataset.org/train2017/000000109095.jpg',
#   'The worker is pulling or operating some levers at a snow-covered train track or a train yard.'],
#  ['http://images.cocodataset.org/train2017/000000428329.jpg',
#   'The primary setting of the image is a backyard with a patio area.'],
#  ['http://images.cocodataset.org/train2017/000000428329.jpg',
#   'The backyard patio area features patio furniture such as couches and an umbrella, providing shade and comfort for the outdoor space.'],
#  ['http://images.cocodataset.org/train2017/000000428329.jpg',
#   'The surface of the patio is made of concrete.'],
#  ['http://images.cocodataset.org/train2017/000000428329.jpg',
#   'The primary purpose of the umbrella in the patio area is to provide sun shade and protection from the elements, adding comfort to the outdoor seating arrangement.'],
#  ['http://images.cocodataset.org/train2017/000000012805.jpg',
#   'There is a parrot on the refrigerator door.'],
#  ['http://images.cocodataset.org/train2017/000000012805.jpg',
#   'The man is standing in the kitchen, holding open the fridge door, and looking at the parrot sitting on the door.'],
#  ['http://images.cocodataset.org/train2017/000000039446.jpg',
#   "The man is eating pizza as there's a slice of pizza on his plate."],
#  ['http://images.cocodataset.org/train2017/000000039446.jpg',
#   'The man is sitting at a computer desk while eating pizza.'],
#  ['http://images.cocodataset.org/train2017/000000039446.jpg',
#   'A computer keyboard and mouse can be seen near the pizza.'],
#  ['http://images.cocodataset.org/train2017/000000039446.jpg',
#   'The man is holding the plate of pizza over the keyboard.'],
#  ['http://images.cocodataset.org/train2017/000000039446.jpg',
#   'Yes, the person is pointing at their pizza slice near the computer keyboard and mouse.'],
#  ['http://images.cocodataset.org/train2017/000000076590.jpg',
#   'There are two pizzas visible in the image.'],
#  ['http://images.cocodataset.org/train2017/000000076590.jpg',
#   'The pizza is covered in pepperoni and peppers as toppings.'],
#  ['http://images.cocodataset.org/train2017/000000076590.jpg',
#   'Yes, the pizzas are accompanied by plates, silverware, and drinks.'],
#  ['http://images.cocodataset.org/train2017/000000076590.jpg',
#   'The pizzas are placed on a table or counter, with one pizza resting on a metal pizza pan and the other on a plate.'],
#  ['http://images.cocodataset.org/train2017/000000469092.jpg',
#   'The birthday cake in the image is shaped like a castle and is pink in color.'],
#  ['http://images.cocodataset.org/train2017/000000469092.jpg',
#   'Yes, there are cupcakes next to the pink castle-shaped birthday cake.'],
#  ['http://images.cocodataset.org/train2017/000000256155.jpg',
#   'The two men are waiting or sitting in front of the tattoo and piercing shop, accompanied by a dog.'],
#  ['http://images.cocodataset.org/train2017/000000256155.jpg',
#   'The two men and the dog are in front of a tattoo and piercing shop, which provides body art and piercing services to customers.'],
#  ['http://images.cocodataset.org/train2017/000000256155.jpg',
#   'The dog is sitting on the street, along with the two men, in front of the tattoo and piercing shop.'],
#  ['http://images.cocodataset.org/train2017/000000256155.jpg',
#   'The two men are alone with the dog, with no other persons visible in front of the tattoo and piercing shop.'],
#  ['http://images.cocodataset.org/train2017/000000019501.jpg',
#   'The young woman is in a wave pool at a water slide, riding on a bodyboard.'],
#  ['http://images.cocodataset.org/train2017/000000019501.jpg',
#   'The girl is laying on her stomach on the board.'],
#  ['http://images.cocodataset.org/train2017/000000019501.jpg',
#   'The girl is riding a bodyboard, not a surfboard.'],
#  ['http://images.cocodataset.org/train2017/000000049217.jpg',
#   'The man is cross-country skiing through the snowy woods, enjoying the serene winter surroundings.'],
#  ['http://images.cocodataset.org/train2017/000000049217.jpg',
#   'The man is skiing within a wooded area, surrounded by trees and snow-covered paths.'],
#  ['http://images.cocodataset.org/train2017/000000049217.jpg',
#   'The man is wearing short sleeves while skiing in the snow, which is an unusual choice of clothing for such a cold and snowy environment.'],
#  ['http://images.cocodataset.org/train2017/000000281764.jpg',
#   'The dog in the image is a Doberman.'],
#  ['http://images.cocodataset.org/train2017/000000281764.jpg',
#   'The dog in the image appears to have a concerned look on its face.'],
#  ['http://images.cocodataset.org/train2017/000000281764.jpg',
#   'The dog is sitting next to the wooden table, where there is a glass of red wine placed on it.'],
#  ['http://images.cocodataset.org/train2017/000000308098.jpg',
#   'The image depicts a red panda.'],
#  ['http://images.cocodataset.org/train2017/000000308098.jpg',
#   'The red panda is holding some sort of popsicle, which it appears to be licking.'],
#  ['http://images.cocodataset.org/train2017/000000308098.jpg',
#   'The red panda is positioned on a tree branch, with one paw on the log and the other paw holding food to its mouth.'],
#  ['http://images.cocodataset.org/train2017/000000308098.jpg',
#   'Yes, there is a close-up view of the small red panda in the image, allowing us to see more details of the animal and its actions.'],
#  ['http://images.cocodataset.org/train2017/000000365573.jpg',
#   'The man is located at a campsite or picnic area of a park, which has bicycles and a picnic table nearby.'],
#  ['http://images.cocodataset.org/train2017/000000365573.jpg',
#   'The man appears to be taking a break from biking while standing near the bicycles and possibly interacting with other people around him.'],
#  ['http://images.cocodataset.org/train2017/000000365573.jpg',
#   'The man is engaged in biking as an outdoor activity. He is taking a break at a picnic area or a campsite, probably to rest or socialize with other people present at the location.'],
#  ['http://images.cocodataset.org/train2017/000000434602.jpg',
#   'There are three bears in the image: a mother bear and her two cubs.'],
#  ['http://images.cocodataset.org/train2017/000000434602.jpg',
#   'The main activity of the bears in the image is walking or wading across a shallow river.'],
#  ['http://images.cocodataset.org/train2017/000000434602.jpg',
#   'Based on the provided details, there are no other wildlife visible in the image aside from the mother bear and her two cubs.'],
#  ['http://images.cocodataset.org/train2017/000000040068.jpg',
#   'The primary color of the kitchen in the image is white.'],
#  ['http://images.cocodataset.org/train2017/000000040068.jpg',
#   'Yes, there is a window in the kitchen.'],
#  ['http://images.cocodataset.org/train2017/000000040068.jpg',
#   'There is a small portable electric stove sitting on the counter in the kitchen.'],
#  ['http://images.cocodataset.org/train2017/000000040068.jpg',
#   'Yes, the stove is plugged into the wall.'],
#  ['http://images.cocodataset.org/train2017/000000040068.jpg',
#   'Apart from the portable electric stove, a refrigerator can also be seen in the kitchen.'],
#  ['http://images.cocodataset.org/train2017/000000049858.jpg',
#   'The skateboarder in the image is performing a jump while doing an in-air trick, seemingly flying through the air while riding their skateboard.'],
#  ['http://images.cocodataset.org/train2017/000000049858.jpg',
#   'Yes, the skateboarder is wearing safety equipment, including a helmet and safety pads to protect themselves during the skateboarding session.'],
#  ['http://images.cocodataset.org/train2017/000000119994.jpg',
#   'The man in the image is swinging a baseball bat, trying to hit a ball on a field during a baseball game.'],
#  ['http://images.cocodataset.org/train2017/000000119994.jpg',
#   'The man holds the position of a batter in the baseball game, as he is attempting to hit the ball with his bat.'],
#  ['http://images.cocodataset.org/train2017/000000541532.jpg',
#   'There are two traffic lights hanging in the image.'],
#  ['http://images.cocodataset.org/train2017/000000541532.jpg',
#   'One of the traffic lights in the image is red.'],
#  ['http://images.cocodataset.org/train2017/000000541532.jpg',
#   'The traffic lights are suspended from wires at the intersection.'],
#  ['http://images.cocodataset.org/train2017/000000541532.jpg',
#   'The background of the image features a sky with white and blue colors.'],
#  ['http://images.cocodataset.org/train2017/000000071229.jpg',
#   'The main activity happening in the image is a woman, a young girl or female, brushing her hair while seated in front of a mirror.'],
#  ['http://images.cocodataset.org/train2017/000000071229.jpg',
#   'The woman or young girl is wearing a dress in the image.'],
#  ['http://images.cocodataset.org/train2017/000000071229.jpg',
#   'The young female is seated at a desk in front of a mirror while brushing her hair.'],
#  ['http://images.cocodataset.org/train2017/000000071229.jpg',
#   'The person in the image is brushing her hair with a brush.'],
#  ['http://images.cocodataset.org/train2017/000000485202.jpg',
#   'The man in the image is holding a frisbee, preparing to throw it while standing in the woods surrounded by tall trees.'],
#  ['http://images.cocodataset.org/train2017/000000485202.jpg',
#   'The frisbee is red.'],
#  ['http://images.cocodataset.org/train2017/000000485202.jpg',
#   'The man is holding the frisbee in his right hand.'],
#  ['http://images.cocodataset.org/train2017/000000485202.jpg',
#   "The man's face is partially hidden by the frisbee he is holding."],
#  ['http://images.cocodataset.org/train2017/000000335913.jpg',
#   'The size of the bed in the room is a small twin bed.'],
#  ['http://images.cocodataset.org/train2017/000000335913.jpg',
#   'There is a poster on the wall above the bed.'],
#  ['http://images.cocodataset.org/train2017/000000335913.jpg',
#   'Apart from the bed, the bedroom features a bookshelf with many books, a collection of music CDs, a light, and some pictures.'],
#  ['http://images.cocodataset.org/train2017/000000335913.jpg',
#   'The bedspread on the bed is black.'],
#  ['http://images.cocodataset.org/train2017/000000554953.jpg',
#   'There is one person, an older gentleman, featured in the image.'],
#  ['http://images.cocodataset.org/train2017/000000554953.jpg',
#   'The older man is blowing out birthday candles on a cake.'],
#  ['http://images.cocodataset.org/train2017/000000554953.jpg',
#   'The cake is located on a party-decorated table.'],
#  ['http://images.cocodataset.org/train2017/000000015897.jpg',
#   'The woman is holding a brown teddy bear in the image.'],
#  ['http://images.cocodataset.org/train2017/000000015897.jpg',
#   'The woman is putting a teddy bear into a picnic basket.'],
#  ['http://images.cocodataset.org/train2017/000000493252.jpg',
#   'The people in the image are at a train station, waiting for the train to arrive.'],
#  ['http://images.cocodataset.org/train2017/000000493252.jpg',
#   'Reflections of several people standing at the train station can be seen on the side of the subway train.'],
#  ['http://images.cocodataset.org/train2017/000000493252.jpg',
#   'The people are outside the train, waiting for it to arrive or to board it once it stops.'],
#  ['http://images.cocodataset.org/train2017/000000493252.jpg',
#   "A person's reflection can be seen in the train window, indicating that they are standing in front of it, awaiting the train's arrival or boarding."],
#  ['http://images.cocodataset.org/train2017/000000541472.jpg',
#   'The basket contains apples and bananas.'],
#  ['http://images.cocodataset.org/train2017/000000541472.jpg',
#   'The apples are placed below the bananas in the fruit basket.'],
#  ['http://images.cocodataset.org/train2017/000000541472.jpg',
#   'The basket is made of metal or wire.'],
#  ['http://images.cocodataset.org/train2017/000000541472.jpg',
#   'The fruit basket is located on a table.'],
#  ['http://images.cocodataset.org/train2017/000000493841.jpg',
#   'The main object in this image is a large green pillar with a clock on top of it, which is located in the middle of the city.'],
#  ['http://images.cocodataset.org/train2017/000000493841.jpg',
#   'The person standing next to the clock pillar is wearing pink slacks.'],
#  ['http://images.cocodataset.org/train2017/000000493841.jpg',
#   'The clock is positioned on top of a large green pillar, which is situated in an urban, public setting in the middle of the city.'],
#  ['http://images.cocodataset.org/train2017/000000266360.jpg',
#   'In the image, there is a large teddy bear holding a smaller teddy bear.'],
#  ['http://images.cocodataset.org/train2017/000000266360.jpg',
#   'There is a price tag attached to the ear of the teddy bears, indicating that they are for sale.'],
#  ['http://images.cocodataset.org/train2017/000000266360.jpg',
#   'The color of both teddy bears is brown.'],
#  ['http://images.cocodataset.org/train2017/000000266360.jpg',
#   'The large teddy bear is hugging or holding the smaller teddy bear, creating a tender and comforting scene.'],
#  ['http://images.cocodataset.org/train2017/000000256968.jpg',
#   'The skateboarding is taking place indoors, specifically at an indoor skate park.'],
#  ['http://images.cocodataset.org/train2017/000000256968.jpg',
#   'The man is skateboarding on the edge of a skateboard ramp or at the top of a bowl in the indoor skate park.'],
#  ['http://images.cocodataset.org/train2017/000000256968.jpg',
#   'The person skateboarding is male.'],
#  ['http://images.cocodataset.org/train2017/000000100638.jpg',
#   'The man and the woman are playing a boxing video game together, likely using the motion-sensitive Wii remotes to control their characters on-screen.'],
#  ['http://images.cocodataset.org/train2017/000000100638.jpg',
#   'There are two people in the image, a man and a woman, who are standing in front of a big-screen TV and playing a video game together, specifically a Wii boxing game using the Wii remotes.'],
#  ['http://images.cocodataset.org/train2017/000000100638.jpg',
#   "Based on the image's description of the two people holding Wii remotes, it is likely that the gaming console they are using is a Nintendo Wii."],
#  ['http://images.cocodataset.org/train2017/000000069029.jpg',
#   'The skateboarder is performing a trick on a bench.'],
#  ['http://images.cocodataset.org/train2017/000000069029.jpg',
#   'The skateboarder appears to be in the younger age group, as he is described as a boy or young man.'],
#  ['http://images.cocodataset.org/train2017/000000069029.jpg',
#   'The skateboarder is performing the trick in a park, possibly within an enclosed area specifically designed for skateboarding activities.'],
#  ['http://images.cocodataset.org/train2017/000000288694.jpg',
#   'The boy in the image is holding a baseball bat.'],
#  ['http://images.cocodataset.org/train2017/000000288694.jpg',
#   'The boy is standing outside a building near a wall, with a tree nearby and in an open area. The wall also has graffiti on it.'],
#  ['http://images.cocodataset.org/train2017/000000288694.jpg',
#   'The boy is standing near a building, not on a baseball field. However, he could be in an open area close to a baseball field.'],
#  ['http://images.cocodataset.org/train2017/000000288694.jpg',
#   'There is graffiti on the wall behind the boy.'],
#  ['http://images.cocodataset.org/train2017/000000195155.jpg',
#   'The dog in the image is a boxer breed.'],
#  ['http://images.cocodataset.org/train2017/000000195155.jpg',
#   'The dog is sitting on a computer chair in an office.'],
#  ['http://images.cocodataset.org/train2017/000000195155.jpg',
#   "The dog's facial expression appears stoic as it looks at the camera."],
#  ['http://images.cocodataset.org/train2017/000000195155.jpg',
#   'The dog in the image is brown and white.'],
#  ['http://images.cocodataset.org/train2017/000000112182.jpg',
#   'The woman is standing next to her car, which has surfboards piled on its roof.'],
#  ['http://images.cocodataset.org/train2017/000000112182.jpg',
#   'The woman is wearing pink shorts, and the car is maroon-colored.'],
#  ['http://images.cocodataset.org/train2017/000000112182.jpg',
#   'There are three surfboards on top of the car.'],
#  ['http://images.cocodataset.org/train2017/000000112182.jpg',
#   'The car is a purple SUV, and the woman appears to be of Asian descent.'],
#  ['http://images.cocodataset.org/train2017/000000053232.jpg',
#   'The beds in the image have wooden headboards.'],
#  ['http://images.cocodataset.org/train2017/000000053232.jpg',
#   'The two beds in the image have been made neatly, with nice linen sets on them.'],
#  ['http://images.cocodataset.org/train2017/000000053232.jpg',
#   'The beds sit on a hardwood floor.'],
#  ['http://images.cocodataset.org/train2017/000000311452.jpg',
#   'The image shows a cheese pizza.'],
#  ['http://images.cocodataset.org/train2017/000000311452.jpg',
#   'The entire pizza is visible on the plate, with one slice taken out and laid next to the pizza.'],
#  ['http://images.cocodataset.org/train2017/000000311452.jpg',
#   'Yes, the pizza is fully cooked.'],
#  ['http://images.cocodataset.org/train2017/000000194538.jpg',
#   'The stuffed toy is a multicolored teddy bear with a pleasant face, decorated in several different colors. It appears to be new, as there is a tag still attached to its ear.'],
#  ['http://images.cocodataset.org/train2017/000000161719.jpg',
#   'There are two people in the image, and they are sitting down.'],
#  ['http://images.cocodataset.org/train2017/000000161719.jpg',
#   'The two people, who are women, are sitting down and eating their meals with plates of food in front of them.'],
#  ['http://images.cocodataset.org/train2017/000000161719.jpg',
#   'Yes, there is a dog in the image. The dog is watching the two women as they sit and eat their meals.'],
#  ['http://images.cocodataset.org/train2017/000000161719.jpg',
#   'The setting of the image is indoors, specifically in a room where the two women and the dog are gathered.'],
#  ['http://images.cocodataset.org/train2017/000000188646.jpg',
#   'There are three birds clearly visible in the image.'],
#  ['http://images.cocodataset.org/train2017/000000188646.jpg',
#   'The birds in the image are gray and white.'],
#  ['http://images.cocodataset.org/train2017/000000188646.jpg',
#   'The birds are standing on a sandy beach.'],
#  ['http://images.cocodataset.org/train2017/000000188646.jpg',
#   'Yes, there are straws lying on the sand near the birds.'],
#  ['http://images.cocodataset.org/train2017/000000188646.jpg',
#   'The image is focused on one bird in particular, with the other birds in the background.'],
#  ['http://images.cocodataset.org/train2017/000000158853.jpg',
#   'There are two boys in the image, but only one of them is actively skateboarding and maneuvering up a ramp.'],
#  ['http://images.cocodataset.org/train2017/000000158853.jpg',
#   'The skateboarder is wearing jeans while practicing skate tricks on the ramp.'],
#  ['http://images.cocodataset.org/train2017/000000168718.jpg',
#   'The unique feature of the street sign in the image is that it displays the street names in both English and Asian characters, specifically Chinese.'],
#  ['http://images.cocodataset.org/train2017/000000168718.jpg',
#   'A traffic signal, or traffic light, is attached to the same pole as the street sign.'],
#  ['http://images.cocodataset.org/train2017/000000107519.jpg',
#   'The plate of food contains meat, potatoes, and vegetables, specifically string beans.'],
#  ['http://images.cocodataset.org/train2017/000000107519.jpg',
#   'The plate is white.'],
#  ['http://images.cocodataset.org/train2017/000000107519.jpg',
#   'No, I cannot definitively determine the specific type of meat on the plate based on the image. It could be beef, chicken, pork, or another type of meat.'],
#  ['http://images.cocodataset.org/train2017/000000359132.jpg',
#   'The large clock is placed on a trolley, trailer, or truck bed, which is parked in the driveway of a residential home with a two-car garage.'],
#  ['http://images.cocodataset.org/train2017/000000359132.jpg',
#   'The details on the large clock face are black and gold.'],
#  ['http://images.cocodataset.org/train2017/000000359132.jpg',
#   'The clock face is secured onto the parked trailer or truck bed using straps, ensuring it stays in place during transport.'],
#  ['http://images.cocodataset.org/train2017/000000244361.jpg',
# ...
#  ['http://images.cocodataset.org/train2017/000000359507.jpg',
#   'Besides the beds, an empty table can be seen in the room.'],
#  ['http://images.cocodataset.org/train2017/000000359507.jpg',
#   'Yes, the bed is positioned near a window with curtains.'],
#  ['http://images.cocodataset.org/train2017/000000157748.jpg',
#   'The main subject of the image is a tall clock tower located in a city, situated between two buildings and near an intersection.'],
#  ['http://images.cocodataset.org/train2017/000000157748.jpg',
#   'The clock tower is primarily tan and grey in color.'],
#  ['http://images.cocodataset.org/train2017/000000157748.jpg',
#   'The clock tower has a newer-looking design, suggesting that it is a more modern structure.'],
#  ['http://images.cocodataset.org/train2017/000000157748.jpg',
#   'Two clock faces are visible on the clock tower.'],
#  ['http://images.cocodataset.org/train2017/000000039012.jpg',
#   'The fire hydrant in the image is white.'],
#  ['http://images.cocodataset.org/train2017/000000039012.jpg',
#   'The fire hydrant is located in a grassy environment, possibly a park.'],
#  ['http://images.cocodataset.org/train2017/000000039012.jpg',
#   'Yes, there are some rocks near the fire hydrant in the image.'],
#  ['http://images.cocodataset.org/train2017/000000196623.jpg',
#   'The cat in the image is grey.'],
#  ['http://images.cocodataset.org/train2017/000000196623.jpg',
#   'The cat is wearing a festive, red and green fuzzy elf hat.'],
#  ['http://images.cocodataset.org/train2017/000000196623.jpg',
#   'Yes, the cat is being petted while wearing the elf hat.'],
#  ['http://images.cocodataset.org/train2017/000000196623.jpg',
#   'The cat is laying on a knit blanket.'],
#  ['http://images.cocodataset.org/train2017/000000196623.jpg',
#   'The theme of the hat the cat is wearing is Christmas.'],
#  ['http://images.cocodataset.org/train2017/000000238905.jpg',
#   'The man in the image, who is wearing a baseball uniform, is swinging a baseball bat at a ball. He is taking a swing at a pitch, attempting to hit the ball during a baseball game.'],
#  ['http://images.cocodataset.org/train2017/000000238905.jpg',
#   'The man in the image is wearing a baseball uniform, which typically consists of a jersey, baseball pants, cleats, a cap, and other protective gear such as a helmet, sliding shorts, and batting gloves.'],
#  ['http://images.cocodataset.org/train2017/000000238905.jpg',
#   'The key action being performed by the baseball player in the image is swinging a bat at a pitch, attempting to make contact with the ball and hit it into play during the game.'],
#  ['http://images.cocodataset.org/train2017/000000106658.jpg',
#   'The image shows a large white commercial airliner flying in the air. It is not specifically a FedEx package transport plane.'],
#  ['http://images.cocodataset.org/train2017/000000106658.jpg',
#   'The airplane is flying in front of a beautiful mountain range with clouds surrounding the area, creating a picturesque and majestic backdrop.'],
#  ['http://images.cocodataset.org/train2017/000000106658.jpg',
#   'The airplane is already in flight, as it is flying in front of the mountains and clouds rather than taking off from an airport.'],
#  ['http://images.cocodataset.org/train2017/000000120615.jpg',
#   'The towels in the bathroom are red.'],
#  ['http://images.cocodataset.org/train2017/000000120615.jpg',
#   'The bathroom floor is white.'],
#  ['http://images.cocodataset.org/train2017/000000120615.jpg',
#   'The toilet is located underneath the rack of red towels.'],
#  ['http://images.cocodataset.org/train2017/000000120615.jpg',
#   'A shower is located close to the toilet in the bathroom.'],
#  ['http://images.cocodataset.org/train2017/000000120615.jpg',
#   'It is likely that the bathroom is in a residential home, as it is described as a "home bathroom" with a towel rack above the toilet.'],
#  ['http://images.cocodataset.org/train2017/000000196974.jpg',
#   'A blueberry crumb cake is on a plate next to the almonds.'],
#  ['http://images.cocodataset.org/train2017/000000141955.jpg',
#   'There are three kittens in the image.'],
#  ['http://images.cocodataset.org/train2017/000000141955.jpg',
#   'The carpet/mat in the bathroom is pink and white.'],
#  ['http://images.cocodataset.org/train2017/000000141955.jpg',
#   'The kittens are curled up and sleeping on the rug in the bathroom.'],
#  ['http://images.cocodataset.org/train2017/000000021569.jpg',
#   'The truck in the image is red and white.'],
#  ['http://images.cocodataset.org/train2017/000000021569.jpg',
#   'The truck is traveling on a wet road, which could be due to rain or other weather conditions.'],
#  ['http://images.cocodataset.org/train2017/000000021569.jpg',
#   'The truck is pulling a trailer along the wet road.'],
#  ['http://images.cocodataset.org/train2017/000000021569.jpg',
#   'The truck is driving through an area with a forest, suggesting that it is traveling in a more rural or natural environment.'],
#  ['http://images.cocodataset.org/train2017/000000021569.jpg',
#   'The truck is driving up a hill road. The presence of a hill indicates some inclination, which the truck has to negotiate while traveling on this wet road.'],
#  ['http://images.cocodataset.org/train2017/000000546046.jpg',
#   'There are three double-decker buses in the image.'],
#  ['http://images.cocodataset.org/train2017/000000546046.jpg',
#   'In the image, there are two large red double-decker buses and one blue double-decker bus.'],
#  ['http://images.cocodataset.org/train2017/000000546046.jpg',
#   'The buses are parked side by side, lined up next to each other on the road.'],
#  ['http://images.cocodataset.org/train2017/000000546046.jpg',
#   'The buses appear to be parked, as they are lined up next to each other on the road.'],
#  ['http://images.cocodataset.org/train2017/000000572362.jpg',
#   'There are two people in the image.'],
#  ['http://images.cocodataset.org/train2017/000000572362.jpg',
#   'The two people are walking down a road or a city street together while sharing a yellow umbrella in the rain.'],
#  ['http://images.cocodataset.org/train2017/000000572362.jpg',
#   'The weather in the image is rainy, as the two people are using an umbrella to protect themselves from the rain while walking.'],
#  ['http://images.cocodataset.org/train2017/000000572362.jpg',
#   'The umbrella the two people are sharing is yellow.'],
#  ['http://images.cocodataset.org/train2017/000000153845.jpg',
#   'There are three wine glasses in the image.'],
#  ['http://images.cocodataset.org/train2017/000000153845.jpg',
#   'The wine glass holder is black.'],
#  ['http://images.cocodataset.org/train2017/000000153845.jpg',
#   'The wine glasses have wine in them, with three different selections of drinks.'],
#  ['http://images.cocodataset.org/train2017/000000153845.jpg',
#   'The wine glasses are suspended in the air on a wine glass stand.'],
#  ['http://images.cocodataset.org/train2017/000000099966.jpg',
#   'There are two men visible in the kitchen, both of whom are busy preparing food for customers.'],
#  ['http://images.cocodataset.org/train2017/000000099966.jpg',
#   "The men are wearing chef uniforms, indicating that they are professional chefs working in a restaurant's kitchen."],
#  ['http://images.cocodataset.org/train2017/000000389935.jpg',
#   'The person with the snowboard is sitting on the snow-covered slope with the snowboard attached to their feet.'],
#  ['http://images.cocodataset.org/train2017/000000389935.jpg',
#   'There are two people visible in the image - one person sitting on the ground with a snowboard attached to their feet, and another person standing above them.'],
#  ['http://images.cocodataset.org/train2017/000000389935.jpg',
#   'Once the snowboarder stands up, they will likely be engaged in snowboarding down the snowy hill, maneuvering and carving turns while enjoying the winter sport.'],
#  ['http://images.cocodataset.org/train2017/000000108100.jpg',
#   'The people in the image are standing around together near an umbrella.'],
#  ['http://images.cocodataset.org/train2017/000000268656.jpg',
#   'There are two skateboarders in the image.'],
#  ['http://images.cocodataset.org/train2017/000000268656.jpg',
#   'The skateboarders are at a skateboard park, and they are in midair while performing tricks, possibly at the top of a half-pipe.'],
#  ['http://images.cocodataset.org/train2017/000000268656.jpg',
#   'The skateboarders are in the air, as they are performing midair tricks on their skateboards.'],
#  ['http://images.cocodataset.org/train2017/000000268656.jpg',
#   'The skateboarders are executing tricks with their skateboards, demonstrating their skills and control.'],
#  ['http://images.cocodataset.org/train2017/000000541105.jpg',
#   'The primary focus of the image is a person holding a hot dog with ketchup on it.'],
#  ['http://images.cocodataset.org/train2017/000000541105.jpg',
#   'The hot dog has ketchup as a condiment on it.'],
#  ['http://images.cocodataset.org/train2017/000000541105.jpg',
#   'A woman is holding the hot dog in the image.'],
#  ['http://images.cocodataset.org/train2017/000000541105.jpg',
#   'Yes, the hot dog is served in a bun.'],
#  ['http://images.cocodataset.org/train2017/000000403986.jpg',
#   'The sport depicted in the image is baseball.'],
#  ['http://images.cocodataset.org/train2017/000000403986.jpg',
#   'The baseball player in the image is swinging a bat at a ball during a baseball game. It is an action shot capturing the intensity of the sport.'],
#  ['http://images.cocodataset.org/train2017/000000440577.jpg',
#   'The train described in the image is carrying cargo, making it a freight train.'],
#  ['http://images.cocodataset.org/train2017/000000440577.jpg',
#   'A body of water, possibly a lake, is located near the train tracks.'],
#  ['http://images.cocodataset.org/train2017/000000440577.jpg',
#   'A highway is located near the train tracks.'],
#  ['http://images.cocodataset.org/train2017/000000460287.jpg',
#   'The dog is laying on the floor in front of a bookcase, seemingly showing interest in a book.'],
#  ['http://images.cocodataset.org/train2017/000000460287.jpg',
#   'The dog appears to be looking at a book called "The Marriage of True Minds" by Stephen Evans.'],
#  ['http://images.cocodataset.org/train2017/000000460287.jpg',
#   'The dog is laying down on the floor in the image.'],
#  ['http://images.cocodataset.org/train2017/000000170529.jpg',
#   'There is an old-fashioned wheelchair, mostly made of wood, in the middle of the room.'],
#  ['http://images.cocodataset.org/train2017/000000170529.jpg',
#   'The room setting includes a wheelchair, a desk, and a window. The wheelchair is sitting in the living room, next to the window. There is also a cloth on the back of the vintage chair.'],
#  ['http://images.cocodataset.org/train2017/000000170529.jpg',
#   'The old wheelchair is primarily made of wood.'],
#  ['http://images.cocodataset.org/train2017/000000170529.jpg',
#   'Apart from the wheelchair, a desk and a window are visible in the room.'],
#  ['http://images.cocodataset.org/train2017/000000053304.jpg',
#   'The person in the image is wearing a white jacket, indicating that they are a chef.'],
#  ['http://images.cocodataset.org/train2017/000000053304.jpg',
#   'The chef in the kitchen is preparing and plating food. They are spooning out their creation onto a dish, placing a dollop of some food on a plate, and scooping food onto another plate.'],
#  ['http://images.cocodataset.org/train2017/000000053304.jpg',
#   'The image shows a professional kitchen, as evidenced by the presence of a chef in a white jacket, who is working on preparing and plating food.'],
#  ['http://images.cocodataset.org/train2017/000000001888.jpg',
#   'On the cutting board in the image, there is a raw cut of meat still on the bone, along with some apple slices and leaves. The meat appears to be seasoned or in the process of being seasoned.'],
#  ['http://images.cocodataset.org/train2017/000000001888.jpg',
#   "Yes, someone is seasoning the meat in the image. A person's left hand is sprinkling spices on the raw chops placed on the cutting board."],
#  ['http://images.cocodataset.org/train2017/000000368409.jpg',
#   'The main subject of the image is a woman walking across a city street in the rain, holding an umbrella.'],
#  ['http://images.cocodataset.org/train2017/000000368409.jpg',
#   'The woman is holding a black umbrella to protect herself from the rain.'],
#  ['http://images.cocodataset.org/train2017/000000368409.jpg',
#   'Yes, there are a couple of other people crossing the street in front of cars along with the woman.'],
#  ['http://images.cocodataset.org/train2017/000000368409.jpg',
#   'A tall cross can be seen by the street in the big city, which might be a traffic signal or a street sign.'],
#  ['http://images.cocodataset.org/train2017/000000368409.jpg',
#   'Yes, the street appears to be busy with traffic, as the woman and a couple of other people are crossing the street in front of cars.'],
#  ['http://images.cocodataset.org/train2017/000000285131.jpg',
#   "The setting of the image is a city street with cars driving past tall buildings, and traffic is visible on the road. There's also an intersection nearby."],
#  ['http://images.cocodataset.org/train2017/000000285131.jpg',
#   'Yes, there is an arrow pointing to a sign in the image, and there is also a red arrow pointing towards a street sign sitting on a sidewalk.'],
#  ['http://images.cocodataset.org/train2017/000000310968.jpg',
#   'No, the man is not wearing a shirt while skateboarding. He is wearing only shorts.'],
#  ['http://images.cocodataset.org/train2017/000000310968.jpg',
#   'The man is wearing a headband on his head.'],
#  ['http://images.cocodataset.org/train2017/000000463318.jpg',
#   'The greenery and flowers are being held in a vase.'],
#  ['http://images.cocodataset.org/train2017/000000463318.jpg',
#   'The arrangement in the vase consists of both plastic greenery and dried flowers, which together create an elegant effect over a frosted vase.'],
#  ['http://images.cocodataset.org/train2017/000000463318.jpg',
#   'The vase is placed on a table in a restaurant, likely serving as a decorative centerpiece for the dining area.'],
#  ['http://images.cocodataset.org/train2017/000000463318.jpg',
#   'The vase contains an arrangement of exotic or tropical flowers, along with the plastic greenery.'],
#  ['http://images.cocodataset.org/train2017/000000291921.jpg',
#   'The person in the image is wearing a wet suit while surfing.'],
#  ['http://images.cocodataset.org/train2017/000000291921.jpg',
#   'The person is riding a surfboard on a wave in the ocean.'],
#  ['http://images.cocodataset.org/train2017/000000291921.jpg',
#   'Yes, there is water spray visible in the image as the surfer rides the wave.'],
#  ['http://images.cocodataset.org/train2017/000000291921.jpg',
#   'The surfer is finishing a run and is about to be overcome by a large wave.'],
#  ['http://images.cocodataset.org/train2017/000000530001.jpg',
#   'The kitchen has several appliances, including a stove, oven, dishwasher, and a microwave.'],
#  ['http://images.cocodataset.org/train2017/000000530001.jpg',
#   'The kitchen is clean and well-organized, with an abundance of kitchen supplies.'],
#  ['http://images.cocodataset.org/train2017/000000530001.jpg',
#   'The cabinets in the kitchen are brown, as they are made of unstained wood.'],
#  ['http://images.cocodataset.org/train2017/000000530001.jpg',
#   'There is a dining table present in the kitchen, which provides a space for meals and gatherings.'],
#  ['http://images.cocodataset.org/train2017/000000535786.jpg',
#   'The toilet in the image is white.'],
#  ['http://images.cocodataset.org/train2017/000000535786.jpg',
#   'The toilet is decorated with a red bow or ribbon, giving it the appearance of being carefully gift-wrapped.'],
#  ['http://images.cocodataset.org/train2017/000000535786.jpg',
#   'The toilet is located inside a bathroom.'],
#  ['http://images.cocodataset.org/train2017/000000141723.jpg',
#   'The woman in the image is wearing cowboy boots.'],
#  ['http://images.cocodataset.org/train2017/000000141723.jpg',
#   'The woman is talking on her cell phone while standing on a sidewalk.'],
#  ...]

# %%
df = pd.DataFrame(data_instruct150_sample_val_flatten, columns=['image_url', 'caption'])

# %%
pickle_file = 'captions.pickle'  # Replace with your desired output path
df.to_pickle(pickle_file)
